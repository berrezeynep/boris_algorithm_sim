# %%
# Bu satır grafiğin satırın hemen altında çıkmasını sağlar
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# --- 1. Veriyi Oku ---
file_name = 'particle_trajectory2.dat'

try:
    # Veriyi yükle
    data = np.loadtxt(file_name, delimiter='\t', skiprows=1)
    
    # Sütunları ayır
    t = data[:, 0]
    x = data[:, 1]
    y = data[:, 2]
    z = data[:, 3]

    # --- 2. Grafiği Çiz ---
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    # Parçacığı çiz
    ax.plot(x, y, z, label='Elektron Yörüngesi', color='blue', linewidth=2)

    # Görsellik Ayarları
    ax.set_title('Manyetik Alanda Parçacık Hareketi (Synchrotron)', fontsize=14)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.legend()
    
    # Grafiği göster
    plt.show()

except FileNotFoundError:
    print("HATA: .dat dosyası bulunamadı")

# %%
# Bu satır grafiğin satırın hemen altında çıkmasını sağlar
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# --- 1. Veriyi Oku ---
file_name = 'trajectory_boris.dat'

try:
    # Veriyi yükle
    data = np.loadtxt(file_name, delimiter='\t', skiprows=1)
    
    # Sütunları ayır
    t = data[:, 0]
    x = data[:, 1]
    y = data[:, 2]
    z = data[:, 3]

    # --- 2. Grafiği Çiz ---
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    # Parçacığı çiz
    ax.plot(x, y, z, label='Elektron Yörüngesi', color='blue', linewidth=2)

    # Görsellik Ayarları
    ax.set_title('Manyetik Alanda Parçacık Hareketi (Synchrotron)', fontsize=14)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.legend()
    
    # Grafiği göster
    plt.show()

except FileNotFoundError:
    print("HATA: .dat dosyası bulunamadı")

# %%
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

file_name = 'trajectory_boris2.dat'

try:

    data = np.loadtxt(file_name, delimiter='\t', skiprows=1)

    t = data[:, 0]
    x = data[:, 1]
    y = data[:, 2]
    z = data[:, 3]
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    ax.plot(x, y, z, label='Elektron Yörüngesi', color='blue', linewidth=2)

    ax.set_title('Manyetik Alanda Parçacık Hareketi (Synchrotron)', fontsize=14)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_zlim(np.min(z), np.max(z))
    ax.legend()

    plt.show()

except FileNotFoundError:
    print("HATA: .dat dosyası bulunamadı")
